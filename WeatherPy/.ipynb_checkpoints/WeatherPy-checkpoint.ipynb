# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import scipy.stats as st
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
cities_dict = {
    "city": cities
}
city_list = pd.DataFrame(cities_dict)
city_list
# Out:
#             city
# 0         albany
# 1       koundara
# 2    mitsamiouli
# 3    znamenskoye
# 4           hilo
# ..           ...
# 628        bundi
# 629        sadat
# 630   magdagachi
# 631   landerneau
# 632      whyalla
#
# [633 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.

weather = []

print("Beginning Data Retrieval")
print("---------------------------")

rec = 0
sets = 1

for city in cities:
    rec += 1
    print(f"Processing Record {rec} of Set {sets} | {city}")
    
    if rec == 50:
        sets += 1
        rec = 0
        
    try:
        url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
        response = requests.get(url).json()
        weather.append({
            "City": city,
            "Lat": response["coord"]["lat"],
            "Long": response["coord"]["lon"],
            "Max Temp": response["main"]["temp_max"],
            "Humidity": response["main"]["humidity"],
            "Wind": response["wind"]["speed"],
            "Cloudiness": response["clouds"]["all"],
            "Country": response["sys"]["country"],
            "Date": response["dt"]
        })
    except:
        print("City not found. Skipping...")
        pass                        

print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | koundara
# Processing Record 3 of Set 1 | mitsamiouli
# Processing Record 4 of Set 1 | znamenskoye
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | bukama
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | samfya
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 | ambanja
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | kashi
# Processing Record 17 of Set 1 | acapulco
# Processing Record 18 of Set 1 | placido de castro
# Processing Record 19 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 20 of Set 1 | pindi bhattian
# Processing Record 21 of Set 1 | maniitsoq
# Processing Record 22 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 1 | lubu
# Processing Record 24 of Set 1 | oranjemund
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | cabedelo
# Processing Record 28 of Set 1 | rio verde de mato grosso
# Processing Record 29 of Set 1 | belmonte
# Processing Record 30 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 31 of Set 1 | alta floresta
# Processing Record 32 of Set 1 | asau
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | kupino
# Processing Record 35 of Set 1 | rodrigues alves
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | formosa
# Processing Record 40 of Set 1 | waipawa
# Processing Record 41 of Set 1 | hampton
# Processing Record 42 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | hami
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | ibatiba
# Processing Record 47 of Set 1 | ambulu
# Processing Record 48 of Set 1 | keuruu
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | leningradskiy
# Processing Record 1 of Set 2 | porto torres
# Processing Record 2 of Set 2 | meulaboh
# Processing Record 3 of Set 2 | sao joao da barra
# Processing Record 4 of Set 2 | tarakan
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | coahuayana
# Processing Record 8 of Set 2 | vestmannaeyjar
# Processing Record 9 of Set 2 | abu samrah
# Processing Record 10 of Set 2 | vila franca do campo
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 2 | saint anthony
# Processing Record 15 of Set 2 | kasongo-lunda
# Processing Record 16 of Set 2 | sao filipe
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | boundiali
# Processing Record 20 of Set 2 | saint-francois
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | palmer
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | cabo san lucas
# Processing Record 26 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | kargasok
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | houma
# Processing Record 39 of Set 2 | cap malheureux
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | bubaque
# Processing Record 44 of Set 2 | iskateley
# Processing Record 45 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 2 | menongue
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | les cayes
# Processing Record 49 of Set 2 | itoman
# Processing Record 50 of Set 2 | brae
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 3 | paamiut
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | ninghai
# Processing Record 7 of Set 3 | lazaro cardenas
# Processing Record 8 of Set 3 | male
# Processing Record 9 of Set 3 | kalaleh
# Processing Record 10 of Set 3 | sheridan
# Processing Record 11 of Set 3 | road town
# Processing Record 12 of Set 3 | port hardy
# Processing Record 13 of Set 3 | novoagansk
# Processing Record 14 of Set 3 | tripoli
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | dwarka
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | leshukonskoye
# Processing Record 19 of Set 3 | mataura
# Processing Record 20 of Set 3 | sassandra
# Processing Record 21 of Set 3 | vao
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | kosonsoy
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | urumqi
# Processing Record 27 of Set 3 | burnie
# Processing Record 28 of Set 3 | haines junction
# Processing Record 29 of Set 3 | lahij
# Processing Record 30 of Set 3 | vastervik
# City not found. Skipping...
# Processing Record 31 of Set 3 | tambura
# Processing Record 32 of Set 3 | grand gaube
# Processing Record 33 of Set 3 | ciudad bolivar
# Processing Record 34 of Set 3 | bonnyville
# Processing Record 35 of Set 3 | alihe
# Processing Record 36 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 37 of Set 3 | metro
# Processing Record 38 of Set 3 | namatanai
# Processing Record 39 of Set 3 | chapais
# Processing Record 40 of Set 3 | coihaique
# Processing Record 41 of Set 3 | hay river
# Processing Record 42 of Set 3 | marawi
# Processing Record 43 of Set 3 | san cristobal
# Processing Record 44 of Set 3 | villa carlos paz
# Processing Record 45 of Set 3 | te anau
# Processing Record 46 of Set 3 | yeniseysk
# Processing Record 47 of Set 3 | gogrial
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | saldanha
# Processing Record 4 of Set 4 | cedar city
# Processing Record 5 of Set 4 | alofi
# Processing Record 6 of Set 4 | tashara
# Processing Record 7 of Set 4 | ternate
# Processing Record 8 of Set 4 | fonte boa
# Processing Record 9 of Set 4 | altus
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | lavrentiya
# Processing Record 13 of Set 4 | isangel
# Processing Record 14 of Set 4 | north bend
# Processing Record 15 of Set 4 | bereda
# Processing Record 16 of Set 4 | fuerte olimpo
# Processing Record 17 of Set 4 | portland
# Processing Record 18 of Set 4 | vila velha
# Processing Record 19 of Set 4 | berlevag
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | sungaipenuh
# Processing Record 22 of Set 4 | ulaangom
# Processing Record 23 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | saint-augustin
# Processing Record 26 of Set 4 | tonota
# Processing Record 27 of Set 4 | kodiak
# Processing Record 28 of Set 4 | beisfjord
# Processing Record 29 of Set 4 | verkhoyansk
# Processing Record 30 of Set 4 | padang
# Processing Record 31 of Set 4 | bonavista
# Processing Record 32 of Set 4 | hammerfest
# Processing Record 33 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 4 | riyadh
# Processing Record 35 of Set 4 | celestun
# Processing Record 36 of Set 4 | terrace
# Processing Record 37 of Set 4 | ponta do sol
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | cantanhede
# Processing Record 40 of Set 4 | moerai
# Processing Record 41 of Set 4 | disna
# Processing Record 42 of Set 4 | wasilla
# Processing Record 43 of Set 4 | broome
# Processing Record 44 of Set 4 | kiruna
# Processing Record 45 of Set 4 | mayo
# Processing Record 46 of Set 4 | cascais
# Processing Record 47 of Set 4 | sinnamary
# Processing Record 48 of Set 4 | ixtapa
# Processing Record 49 of Set 4 | kakonko
# Processing Record 50 of Set 4 | pingzhuang
# Processing Record 1 of Set 5 | azanka
# Processing Record 2 of Set 5 | warrnambool
# Processing Record 3 of Set 5 | uvalde
# Processing Record 4 of Set 5 | varena
# Processing Record 5 of Set 5 | passo de camaragibe
# Processing Record 6 of Set 5 | norman wells
# Processing Record 7 of Set 5 | victor harbor
# Processing Record 8 of Set 5 | camocim
# Processing Record 9 of Set 5 | sao felix do xingu
# Processing Record 10 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 5 | cherskiy
# Processing Record 12 of Set 5 | thaba-tseka
# Processing Record 13 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 5 | riihimaki
# Processing Record 15 of Set 5 | malartic
# Processing Record 16 of Set 5 | chernyshevskiy
# Processing Record 17 of Set 5 | guerrero negro
# Processing Record 18 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 5 | mankono
# Processing Record 20 of Set 5 | kigorobya
# Processing Record 21 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 22 of Set 5 | chimoio
# Processing Record 23 of Set 5 | yar-sale
# Processing Record 24 of Set 5 | sabang
# Processing Record 25 of Set 5 | andra
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | odienne
# Processing Record 28 of Set 5 | frumusita
# Processing Record 29 of Set 5 | qaanaaq
# Processing Record 30 of Set 5 | erzin
# Processing Record 31 of Set 5 | margate
# Processing Record 32 of Set 5 | romanovo
# Processing Record 33 of Set 5 | nevers
# Processing Record 34 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 5 | marienburg
# Processing Record 36 of Set 5 | tsiroanomandidy
# Processing Record 37 of Set 5 | manggar
# Processing Record 38 of Set 5 | saint-joseph
# Processing Record 39 of Set 5 | esperance
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | agadir
# Processing Record 42 of Set 5 | turukhansk
# Processing Record 43 of Set 5 | laguna
# Processing Record 44 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 5 | victoria
# Processing Record 47 of Set 5 | chokurdakh
# Processing Record 48 of Set 5 | thio
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | omboue
# Processing Record 2 of Set 6 | maldonado
# Processing Record 3 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 6 | karratha
# Processing Record 5 of Set 6 | brandon
# Processing Record 6 of Set 6 | waingapu
# Processing Record 7 of Set 6 | pozo colorado
# Processing Record 8 of Set 6 | beipiao
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | luganville
# Processing Record 11 of Set 6 | kandry
# Processing Record 12 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 6 | alcala de henares
# Processing Record 14 of Set 6 | salalah
# Processing Record 15 of Set 6 | voisiku
# City not found. Skipping...
# Processing Record 16 of Set 6 | emba
# Processing Record 17 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 6 | yarmouth
# Processing Record 19 of Set 6 | kabompo
# Processing Record 20 of Set 6 | moron
# Processing Record 21 of Set 6 | magam
# Processing Record 22 of Set 6 | medea
# Processing Record 23 of Set 6 | fairbanks
# Processing Record 24 of Set 6 | taoudenni
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | sidrolandia
# Processing Record 27 of Set 6 | thompson
# Processing Record 28 of Set 6 | norilsk
# Processing Record 29 of Set 6 | mehamn
# Processing Record 30 of Set 6 | luba
# Processing Record 31 of Set 6 | padinska skela
# Processing Record 32 of Set 6 | constitucion
# Processing Record 33 of Set 6 | itaperuna
# Processing Record 34 of Set 6 | marsh harbour
# Processing Record 35 of Set 6 | zalantun
# Processing Record 36 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 6 | texarkana
# Processing Record 38 of Set 6 | islampur
# Processing Record 39 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 6 | high level
# Processing Record 41 of Set 6 | goderich
# Processing Record 42 of Set 6 | manicore
# Processing Record 43 of Set 6 | yeppoon
# Processing Record 44 of Set 6 | abeche
# Processing Record 45 of Set 6 | rio gallegos
# Processing Record 46 of Set 6 | adrar
# Processing Record 47 of Set 6 | luancheng
# Processing Record 48 of Set 6 | quelimane
# Processing Record 49 of Set 6 | dikaia
# City not found. Skipping...
# Processing Record 50 of Set 6 | tyrma
# Processing Record 1 of Set 7 | washington
# Processing Record 2 of Set 7 | talcahuano
# Processing Record 3 of Set 7 | levelland
# Processing Record 4 of Set 7 | hualmay
# Processing Record 5 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 7 | kaitangata
# Processing Record 7 of Set 7 | kenai
# Processing Record 8 of Set 7 | korla
# Processing Record 9 of Set 7 | north platte
# Processing Record 10 of Set 7 | tarbes
# Processing Record 11 of Set 7 | fukue
# Processing Record 12 of Set 7 | beloha
# Processing Record 13 of Set 7 | port lincoln
# Processing Record 14 of Set 7 | phalaborwa
# Processing Record 15 of Set 7 | college
# Processing Record 16 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 7 | argelia
# Processing Record 18 of Set 7 | hede
# Processing Record 19 of Set 7 | karachi
# Processing Record 20 of Set 7 | tautira
# Processing Record 21 of Set 7 | hambantota
# Processing Record 22 of Set 7 | kapit
# Processing Record 23 of Set 7 | tera
# Processing Record 24 of Set 7 | nioro
# Processing Record 25 of Set 7 | bengkulu
# Processing Record 26 of Set 7 | machinga
# Processing Record 27 of Set 7 | san quintin
# Processing Record 28 of Set 7 | narsaq
# Processing Record 29 of Set 7 | omagh
# Processing Record 30 of Set 7 | charters towers
# Processing Record 31 of Set 7 | saint george
# Processing Record 32 of Set 7 | dagda
# Processing Record 33 of Set 7 | sar-e pul
# Processing Record 34 of Set 7 | saint andrews
# Processing Record 35 of Set 7 | inhambane
# Processing Record 36 of Set 7 | iraucuba
# Processing Record 37 of Set 7 | denpasar
# Processing Record 38 of Set 7 | alghero
# Processing Record 39 of Set 7 | chuy
# Processing Record 40 of Set 7 | lasa
# Processing Record 41 of Set 7 | longyearbyen
# Processing Record 42 of Set 7 | waddan
# Processing Record 43 of Set 7 | manono
# Processing Record 44 of Set 7 | minas novas
# Processing Record 45 of Set 7 | duki
# Processing Record 46 of Set 7 | bac lieu
# Processing Record 47 of Set 7 | svetlogorsk
# Processing Record 48 of Set 7 | velke mezirici
# Processing Record 49 of Set 7 | pechenga
# Processing Record 50 of Set 7 | fortuna
# Processing Record 1 of Set 8 | mengcheng
# Processing Record 2 of Set 8 | hornepayne
# Processing Record 3 of Set 8 | thinadhoo
# Processing Record 4 of Set 8 | baracoa
# Processing Record 5 of Set 8 | waterford
# Processing Record 6 of Set 8 | huarmey
# Processing Record 7 of Set 8 | brainerd
# Processing Record 8 of Set 8 | svetlaya
# Processing Record 9 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 10 of Set 8 | dingle
# Processing Record 11 of Set 8 | taraz
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | airai
# Processing Record 14 of Set 8 | kununurra
# Processing Record 15 of Set 8 | ahipara
# Processing Record 16 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 17 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 18 of Set 8 | geraldton
# Processing Record 19 of Set 8 | sorland
# Processing Record 20 of Set 8 | kibala
# Processing Record 21 of Set 8 | maneromango
# Processing Record 22 of Set 8 | cairns
# Processing Record 23 of Set 8 | batemans bay
# Processing Record 24 of Set 8 | kahului
# Processing Record 25 of Set 8 | arraial do cabo
# Processing Record 26 of Set 8 | trebinje
# Processing Record 27 of Set 8 | faya
# Processing Record 28 of Set 8 | kerema
# Processing Record 29 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 30 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 8 | grindavik
# Processing Record 32 of Set 8 | floresta
# Processing Record 33 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 35 of Set 8 | krasnorechenskiy
# Processing Record 36 of Set 8 | jalu
# Processing Record 37 of Set 8 | wilmington
# Processing Record 38 of Set 8 | sakakah
# Processing Record 39 of Set 8 | seoul
# Processing Record 40 of Set 8 | buriti bravo
# Processing Record 41 of Set 8 | port blair
# Processing Record 42 of Set 8 | itarema
# Processing Record 43 of Set 8 | kamaishi
# Processing Record 44 of Set 8 | guane
# Processing Record 45 of Set 8 | veraval
# Processing Record 46 of Set 8 | mongoumba
# Processing Record 47 of Set 8 | aykhal
# Processing Record 48 of Set 8 | sokolka
# Processing Record 49 of Set 8 | lagoa
# Processing Record 50 of Set 8 | buluang
# Processing Record 1 of Set 9 | northam
# Processing Record 2 of Set 9 | crestview
# Processing Record 3 of Set 9 | syzran
# Processing Record 4 of Set 9 | privas
# Processing Record 5 of Set 9 | kirakira
# Processing Record 6 of Set 9 | port hawkesbury
# Processing Record 7 of Set 9 | sanandaj
# Processing Record 8 of Set 9 | bairiki
# Processing Record 9 of Set 9 | pushkinskiye gory
# Processing Record 10 of Set 9 | mogadishu
# Processing Record 11 of Set 9 | kelvington
# Processing Record 12 of Set 9 | olafsvik
# Processing Record 13 of Set 9 | ostrovnoy
# Processing Record 14 of Set 9 | havre-saint-pierre
# Processing Record 15 of Set 9 | wladyslawowo
# Processing Record 16 of Set 9 | saran
# Processing Record 17 of Set 9 | naica
# Processing Record 18 of Set 9 | great falls
# Processing Record 19 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 9 | katherine
# Processing Record 21 of Set 9 | namibe
# Processing Record 22 of Set 9 | alakurtti
# Processing Record 23 of Set 9 | masty
# Processing Record 24 of Set 9 | merauke
# Processing Record 25 of Set 9 | calabozo
# Processing Record 26 of Set 9 | ilebo
# Processing Record 27 of Set 9 | araouane
# Processing Record 28 of Set 9 | mount gambier
# Processing Record 29 of Set 9 | tucumcari
# Processing Record 30 of Set 9 | nuristan
# Processing Record 31 of Set 9 | batagay-alyta
# Processing Record 32 of Set 9 | pingliang
# Processing Record 33 of Set 9 | kavieng
# Processing Record 34 of Set 9 | mahuva
# Processing Record 35 of Set 9 | tezu
# Processing Record 36 of Set 9 | sencha
# Processing Record 37 of Set 9 | babu
# Processing Record 38 of Set 9 | saint-pierre
# Processing Record 39 of Set 9 | moree
# Processing Record 40 of Set 9 | jalingo
# Processing Record 41 of Set 9 | fort nelson
# Processing Record 42 of Set 9 | papetoai
# Processing Record 43 of Set 9 | kaeo
# Processing Record 44 of Set 9 | lysyye gory
# Processing Record 45 of Set 9 | peace river
# Processing Record 46 of Set 9 | martapura
# Processing Record 47 of Set 9 | ahuimanu
# Processing Record 48 of Set 9 | zhigansk
# Processing Record 49 of Set 9 | banda aceh
# Processing Record 50 of Set 9 | puerto escondido
# Processing Record 1 of Set 10 | sabibah
# City not found. Skipping...
# Processing Record 2 of Set 10 | saint-felix-de-valois
# Processing Record 3 of Set 10 | xacmaz
# Processing Record 4 of Set 10 | saurimo
# Processing Record 5 of Set 10 | igrim
# Processing Record 6 of Set 10 | ugoofaaru
# Processing Record 7 of Set 10 | usinsk
# Processing Record 8 of Set 10 | suleja
# Processing Record 9 of Set 10 | colares
# Processing Record 10 of Set 10 | sungairaya
# Processing Record 11 of Set 10 | beringovskiy
# Processing Record 12 of Set 10 | hamilton
# Processing Record 13 of Set 10 | rapla
# Processing Record 14 of Set 10 | veracruz
# Processing Record 15 of Set 10 | saskylakh
# Processing Record 16 of Set 10 | yuncheng
# Processing Record 17 of Set 10 | aitape
# Processing Record 18 of Set 10 | sao jose da coroa grande
# Processing Record 19 of Set 10 | russell
# Processing Record 20 of Set 10 | bontang
# Processing Record 21 of Set 10 | comodoro rivadavia
# Processing Record 22 of Set 10 | okha
# Processing Record 23 of Set 10 | praia da vitoria
# Processing Record 24 of Set 10 | arlit
# Processing Record 25 of Set 10 | kristiinankaupunki
# Processing Record 26 of Set 10 | hofn
# Processing Record 27 of Set 10 | loutros
# Processing Record 28 of Set 10 | turayf
# Processing Record 29 of Set 10 | santa rosa
# Processing Record 30 of Set 10 | tizimin
# Processing Record 31 of Set 10 | buraydah
# Processing Record 32 of Set 10 | pundaguitan
# Processing Record 33 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 10 | huilong
# Processing Record 35 of Set 10 | katha
# City not found. Skipping...
# Processing Record 36 of Set 10 | mamit
# Processing Record 37 of Set 10 | nea karvali
# Processing Record 38 of Set 10 | kavaratti
# Processing Record 39 of Set 10 | bagdarin
# Processing Record 40 of Set 10 | half moon bay
# Processing Record 41 of Set 10 | mackay
# Processing Record 42 of Set 10 | touros
# Processing Record 43 of Set 10 | rorvik
# Processing Record 44 of Set 10 | lebanon
# Processing Record 45 of Set 10 | santa quiteria
# Processing Record 46 of Set 10 | aljezur
# Processing Record 47 of Set 10 | abnub
# Processing Record 48 of Set 10 | tura
# Processing Record 49 of Set 10 | pitimbu
# Processing Record 50 of Set 10 | mali
# Processing Record 1 of Set 11 | lodja
# Processing Record 2 of Set 11 | ordynskoye
# Processing Record 3 of Set 11 | bacong
# Processing Record 4 of Set 11 | souillac
# Processing Record 5 of Set 11 | kloulklubed
# Processing Record 6 of Set 11 | porosozero
# Processing Record 7 of Set 11 | zhelyabovka
# Processing Record 8 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 9 of Set 11 | puerto del rosario
# Processing Record 10 of Set 11 | ladovskaya balka
# Processing Record 11 of Set 11 | montepuez
# Processing Record 12 of Set 11 | ereymentau
# Processing Record 13 of Set 11 | flinders
# Processing Record 14 of Set 11 | kudahuvadhoo
# Processing Record 15 of Set 11 | jacareacanga
# Processing Record 16 of Set 11 | srednekolymsk
# Processing Record 17 of Set 11 | avera
# Processing Record 18 of Set 11 | lata
# Processing Record 19 of Set 11 | ibiuna
# Processing Record 20 of Set 11 | vilyuysk
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 11 | yaan
# Processing Record 24 of Set 11 | camopi
# Processing Record 25 of Set 11 | quatre cocos
# Processing Record 26 of Set 11 | jerome
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | aswan
# Processing Record 29 of Set 11 | lompoc
# Processing Record 30 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 11 | abilene
# Processing Record 32 of Set 11 | canoa
# Processing Record 33 of Set 11 | daru
# Processing Record 34 of Set 11 | yakima
# Processing Record 35 of Set 11 | codrington
# Processing Record 36 of Set 11 | novikovo
# Processing Record 37 of Set 11 | saint-leu
# Processing Record 38 of Set 11 | sonegaon
# Processing Record 39 of Set 11 | viransehir
# Processing Record 40 of Set 11 | micheweni
# Processing Record 41 of Set 11 | bogotol
# Processing Record 42 of Set 11 | luderitz
# Processing Record 43 of Set 11 | anadyr
# Processing Record 44 of Set 11 | ketchikan
# Processing Record 45 of Set 11 | zambezi
# Processing Record 46 of Set 11 | san rafael
# Processing Record 47 of Set 11 | bambanglipuro
# Processing Record 48 of Set 11 | sur
# Processing Record 49 of Set 11 | tymovskoye
# Processing Record 50 of Set 11 | clarence town
# Processing Record 1 of Set 12 | green river
# Processing Record 2 of Set 12 | verkhnetulomskiy
# Processing Record 3 of Set 12 | quang ngai
# Processing Record 4 of Set 12 | uspenka
# Processing Record 5 of Set 12 | edgewater
# Processing Record 6 of Set 12 | mukhen
# Processing Record 7 of Set 12 | tabou
# Processing Record 8 of Set 12 | la primavera
# Processing Record 9 of Set 12 | severo-yeniseyskiy
# Processing Record 10 of Set 12 | sompeta
# Processing Record 11 of Set 12 | sayhat
# Processing Record 12 of Set 12 | silver city
# Processing Record 13 of Set 12 | zinder
# Processing Record 14 of Set 12 | dunedin
# Processing Record 15 of Set 12 | boa vista
# Processing Record 16 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 17 of Set 12 | kluczbork
# Processing Record 18 of Set 12 | tecoanapa
# Processing Record 19 of Set 12 | sorong
# Processing Record 20 of Set 12 | faanui
# Processing Record 21 of Set 12 | marzuq
# Processing Record 22 of Set 12 | polson
# Processing Record 23 of Set 12 | gold coast
# Processing Record 24 of Set 12 | san patricio
# Processing Record 25 of Set 12 | san andres
# Processing Record 26 of Set 12 | vung tau
# Processing Record 27 of Set 12 | saint-louis
# Processing Record 28 of Set 12 | vilhena
# Processing Record 29 of Set 12 | helong
# Processing Record 30 of Set 12 | bloemfontein
# Processing Record 31 of Set 12 | troitsko-pechorsk
# Processing Record 32 of Set 12 | mgandu
# Processing Record 33 of Set 12 | lamar
# Processing Record 34 of Set 12 | burica
# City not found. Skipping...
# Processing Record 35 of Set 12 | bucerias
# Processing Record 36 of Set 12 | evensk
# Processing Record 37 of Set 12 | fontenay-le-comte
# Processing Record 38 of Set 12 | takanosu
# Processing Record 39 of Set 12 | saryozek
# Processing Record 40 of Set 12 | vanimo
# Processing Record 41 of Set 12 | yulara
# Processing Record 42 of Set 12 | belaya gora
# Processing Record 43 of Set 12 | zyryanka
# Processing Record 44 of Set 12 | qasigiannguit
# Processing Record 45 of Set 12 | eydhafushi
# Processing Record 46 of Set 12 | bilma
# Processing Record 47 of Set 12 | lokosovo
# Processing Record 48 of Set 12 | lincoln
# Processing Record 49 of Set 12 | mutis
# Processing Record 50 of Set 12 | yagodnoye
# Processing Record 1 of Set 13 | bela
# Processing Record 2 of Set 13 | karpathos
# Processing Record 3 of Set 13 | fort dodge
# Processing Record 4 of Set 13 | gobabis
# Processing Record 5 of Set 13 | kalabo
# Processing Record 6 of Set 13 | tessalit
# Processing Record 7 of Set 13 | skelleftea
# Processing Record 8 of Set 13 | washougal
# Processing Record 9 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 13 | esil
# Processing Record 11 of Set 13 | polovinnoye
# Processing Record 12 of Set 13 | kiama
# Processing Record 13 of Set 13 | saint-jovite
# Processing Record 14 of Set 13 | krasnoyarskiy
# Processing Record 15 of Set 13 | union
# Processing Record 16 of Set 13 | camacha
# Processing Record 17 of Set 13 | necochea
# Processing Record 18 of Set 13 | chepareria
# Processing Record 19 of Set 13 | carlos chagas
# Processing Record 20 of Set 13 | garm
# City not found. Skipping...
# Processing Record 21 of Set 13 | nishihara
# Processing Record 22 of Set 13 | poum
# Processing Record 23 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 24 of Set 13 | marolambo
# Processing Record 25 of Set 13 | nago
# Processing Record 26 of Set 13 | smithers
# Processing Record 27 of Set 13 | price
# Processing Record 28 of Set 13 | plotnikovo
# Processing Record 29 of Set 13 | bundi
# Processing Record 30 of Set 13 | sadat
# Processing Record 31 of Set 13 | magdagachi
# Processing Record 32 of Set 13 | landerneau
# Processing Record 33 of Set 13 | whyalla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display the DataFrame
city_df = pd.DataFrame(weather)
city_df.head()
# Out:
#           City      Lat      Long  Max Temp  Humidity  Wind  Cloudiness  \
# 0       albany  42.6001  -73.9662     37.00        72  7.43         100
# 1     koundara  12.4833  -13.3000     98.17         8  6.22          27
# 2  mitsamiouli -11.3847   43.2844     82.38        76  9.82          28
# 3  znamenskoye  57.1281   73.8282    -10.19        90  5.88          27
# 4         hilo  19.7297 -155.0900     68.00        83  4.61          90
#
#   Country        Date
# 0      US  1610987166
# 1      GN  1610987768
# 2      KM  1610987238
# 3      RU  1610987769
# 4      US  1610987769

# %%
# Export Dataframe into a .csv
city_df.to_csv("cities.csv", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# hum_del = city_df.loc[(city_df["Humidity"])>100]
# print(hum_del)
city_df.describe()
# Out:
#               Lat        Long    Max Temp    Humidity        Wind  Cloudiness  \
# count  579.000000  579.000000  579.000000  579.000000  579.000000  579.000000
# mean    20.698608   15.422774   49.666356   71.143351    8.051174   53.803109
# std     33.393034   89.728431   33.913604   20.964590    5.345427   38.512245
# min    -54.800000 -175.200000  -50.690000    8.000000    0.180000    0.000000
# 25%     -7.385300  -62.449100   28.425000   60.000000    4.090000   14.000000
# 50%     25.933300   22.681400   60.480000   77.000000    6.910000   64.000000
# 75%     48.261900   87.791900   77.810000   86.000000   11.240000   90.000000
# max     78.218600  179.316700   98.170000  100.000000   32.210000  100.000000
#
#                Date
# count  5.790000e+02
# mean   1.610988e+09
# std    2.470282e+02
# min    1.610987e+09
# 25%    1.610988e+09
# 50%    1.610988e+09
# 75%    1.610988e+09
# max    1.610988e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# N/A

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
df = df.an_operation(inplace=False) 

clean_city_data_df = city_df(inplace=False)
clean_city_data_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-917d62b08296> in <module>
#       1 # Make a new DataFrame equal to the city data to drop all humidity outliers by index.
#       2 # Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# ----> 3 clean_city_data_df=city_df(inplace=False)
#       4 clean_city_data_df
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = city_df["lat"]
y_values = city_df["temp_max"]
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-a820a0fd1004> in <module>
# ----> 1 x_values = city_df["lat"]
#       2 y_values = city_df["temp_max"]
#       3 plt.scatter(x_values,y_values)
#       4 plt.xlabel("Latitude")
#       5 plt.ylabel("Temperature")
#
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
